# %%
import numpy as np
a = np.array([[1,2],[4,3]])
b = np.array([[5,6],[7,8]])
add = a + b
print("addition",add)
sub = a - b
print("substract",sub)
multi = a * b
print("multiplication",multi)
trans = np.dot(a,b)
print("transpose",trans)
print(np.transpose(a))
a @ b
import numpy as np
a = np.array([[1,2],[4,3]])
U, S, VT = np.linalg.svd(a)
print("Original matrix")
print(U)

print("\nSingular Values:")
print(S)

print("\nMatrix V^T:")
print(VT)
# Out:
# addition [[ 6  8]
#  [11 11]]
# substract [[-4 -4]
#  [-3 -5]]
# multiplication [[ 5 12]
#  [28 24]]
# transpose [[19 22]
#  [41 48]]
# [[1 4]
#  [2 3]]
# Original matrix
# [[-0.38268343 -0.92387953]
#  [-0.92387953  0.38268343]]
#
# Singular Values:
# [5.39834564 0.92620968]
#
# Matrix V^T:
# [[-0.75545395 -0.65520174]
#  [ 0.65520174 -0.75545395]]

# %%
import matplotlib.pyplot as plt
x = [3,5,6,8,9]
y = [1,2,4,7,2]
plt.plot(x,y)
plt.title("Graph")
plt.xlabel("time")
plt.ylabel("temp")
# Out:
# Text(0, 0.5, 'temp')

# %%
import matplotlib.pyplot as plt
subjects = ["maths","Data structure","python"]
marks = [100,90,50,]
plt.bar(subjects,marks)
plt.title("test")
plt.xlabel("subjects")
plt.ylabel("marks")
# Out:
# Text(0, 0.5, 'marks')

# %%
import matplotlib.pyplot as plt
year = [2022,2023,2024,2025,2026]
Income = [10000,11000,12000,13000,20000]
plt.scatter(year,Income)
plt.title("Salary")
plt.xlabel("year")
plt.ylabel("Income")
# Out:
# Text(0, 0.5, 'Income')

# %%
import matplotlib.pyplot as plt
subjects = ["maths","Data structure","python"]
marks = [100,90,50,]
plt.hist(subjects)
plt.title("test")
plt.xlabel("subjects")
plt.ylabel("marks")
# Out:
# Text(0, 0.5, 'marks')

# %%
import matplotlib.pyplot as plt
subjects = ["maths","Data structure","python"]
marks = [100,90,50,]
plt.hist(subjects)
plt.title("test")
plt.xlabel("subjects")
plt.ylabel("marks")
plt.legend("profit")

# %%
import matplotlib.pyplot as plt
marks = [100,90,50,]
labels = ["maths","Data structure","python"]
plt.pie(marks ,labels=labels)
plt.show
plt.legend("profit")

# %%
import matplotlib.pyplot as plt
marks = [100,90,50,]
subs = ["maths","Data structure","python"]
plt.title("plot")
plt.plot(marks,subs,'r:o')
plt.xlabel("marks")
plt.ylabel("subs")

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = [42, 30, 30, 23, 24]

x = np.array([42, 32, 34, 21, 23])
y = np.array([42, 80, 30, 23, 24])

plt.plot(x, y, marker='*', color='red', linewidth=3, label="Long Line")

plt.plot(
    y,
   x
)

plt.title("Marks Plot")
plt.xlabel("Subjects")
plt.ylabel("Marks")


plt.show()
