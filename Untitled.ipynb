# %%
a=int(input("Enter a number:"))
b=int(input("Enter a number:"))
ch=int(input("Enter your choice\n1.add\n2.Substract\n3.Mutliply\n4.Divide:"))
if ch == 1:
    print("Sum is:", a+b)
elif ch == 2:
   print("sub is:", a-b)
elif ch == 3:    
   print("product is:",a*b)
elif ch == 4:
   print("division is:",a/b)
else:
   print("Invalid choice")
# Out:
# Enter a number:40
# Enter a number:38
# Enter your choice
# 1.add
# 2.Substract
# 3.Mutliply
# 4.Divide:2
# sub is: 2

# %%
a=int(input("Enter first number:"))
b=int(input("Enter second number:"))
if a == b:
    print(a, "and" , b, "are equal")
elif a!=b & (a>=b | a<=b):
        print(a, "and" , b, "are not equal")
else:
    print("Invalid input values")
# Out:
# Enter first number:56
# Enter second number:38
# 56 and 38 are not equal

# %%
dict1= {"name":"ridha", "Rollno":30, "Age":22}
dict2= {"phoneno":9037286906, "place":"calicut","name":"rena"}
dict1.update(dict2)
print(dict1)
# Out:
# {'name': 'rena', 'Rollno': 30, 'Age': 22, 'phoneno': 9037286906, 'place': 'calicut'}

# %%
a=int(input("Enter the first number"))
b=int(input("Enter the second number"))
c=int(input("Enter the third number"))
if a>b & a>c:
    print("Greatest value is:", a)
elif b>a & b>c:
    print("Greatest value is:", b)
else:
    print("Greatest value is:", c)
# Out:
# Enter the first number30
# Enter the second number20
# Enter the third number10
# Greatest value is: 30
